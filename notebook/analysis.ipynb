# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("../data/STUDENT_DATASET.csv")

sns.pairplot(data)
plt.show()

# %% [markdown]
# study hours, attendance and internal marks shows positive correlation with final_score.
# Attendance is strongly connected with final score.
# there is no null values.

# %%
plt.figure()
sns.heatmap(data.corr(),annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure()
plt.scatter(data["study_hours"],data["final_score"])
plt.title("Final Score VS Study hours")
plt.xlabel("Study hours")
plt.ylabel("Final Score")
plt.show()

# %%
plt.figure()
plt.hist(data["final_score"])
plt.title("Distribution of Final Score")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %%
print("Null value count:\n",data.isnull().sum())
# Out:
# Null value count:
#  study_hours       0
# attendance        0
# assignment        0
# internal_marks    0
# final_score       0
# dtype: int64

# %%
data=pd.read_csv("D:/project-1/student-performance-analysis/DATA/STUDENT_DATASET.csv")
print(data.head())
print("Shape of the data:")
print(data.shape)
print("Info about data:")
print(data.info())
print("Description about data:")
print(data.describe())
# Out:
#    study_hours  attendance  assignment  internal_marks  final_score
# 0            7          67          48              38         99.0
# 1            4          75          31              35         99.0
# 2            5          93          39              35         99.0
# 3            7          83          42              22         99.0
# 4            3          59          50              39         99.0
# Shape of the data:
# (100, 5)
# Info about data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   study_hours     100 non-null    int64
#  1   attendance      100 non-null    int64
#  2   assignment      100 non-null    int64
#  3   internal_marks  100 non-null    int64
#  4   final_score     100 non-null    float64
# dtypes: float64(1), int64(4)
# memory usage: 4.0 KB
# None
# Description about data:
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
